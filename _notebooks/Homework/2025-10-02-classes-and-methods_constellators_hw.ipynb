# %% [markdown]
# ---
# layout: post
# toc: True
# breadcrumb: True
# title: CSSE Classes and Methods HW
# description: These are the homework problems and popcorn hacks.
# permalink: /csse/fall_2025/javascript/classes-and-methods/homework
# author: Adya S, Niharika B, Salma Z, Anika S, Sophie H
# categories: ['Javascript', 'Homework']
# ---

# %% [markdown]
# ## **Classes and Methods**

# %% [markdown]
# ### <u>Popcorn Hack 1 - Dice Roller</u>
#
#
# Instructions:
# Finish the code in the cell below (fill in underlines and add lines of code) so it works as described:
#
# - Create a class called Dice that:
#     - Has a property for the number of sides.
#     - Has a method roll() that returns a random number between 1 and the number of sides.
#
#
# At the bottom, test your game by making a DiceGame object and calling roll() a few times.
#
# The code is currently NOT functional. When you have completed this popcorn hack, the code should work. Have fun!

# %%
# %%html
# <h2>Popcorn Hack 1 Output</h2>
# <div id="output1"></div>
#
# <script>
#   (function() {
#     class Dice {
#       constructor(sides) {
#         this.sides = sides;
#       }
#
#       roll() {
#         return Math.floor(Math.random() * this.sides) + 1;
#       }
#     }
#
#     const newDice = new Dice(6);
#     const output = document.getElementById("output1");
#
#     output.innerHTML += "Roll: " + newDice.roll() + "<br>";
#   })();
# </script>
# Out:
# <h2>Popcorn Hack 1 Output</h2>
# <div id="output1"></div>
#
# <script>
#   (function() {
#     class Dice {
#       constructor(sides) {
#         this.sides = sides;
#       }
#
#       roll() {
#         return Math.floor(Math.random() * this.sides) + 1;
#       }
#     }
#
#     const newDice = new Dice(6);
#     const output = document.getElementById("output1");
#
#     output.innerHTML += "Roll 1: " + newDice.roll() + "<br>";
#   })();
# </script>

# %% [markdown]
# ### <u>Popcorn Hack 2 - Pet Simulator</u>
#
#
# This hack is a bit more complicated than the first. Points will be awarded based on effort and completion.
#
#
# Analyze the block of code below. Then, complete the following instructions:
#
#
# 1) Create a simple Pet class by filling in the _________.
#
# 2) Add at least 2 properties (like hunger, energy, or happiness). EX: Stats decrease over time.
#
# 3) Add at least two functioning methods (such as feed, play, or sleep) EX: Buttons increase stats.
#
# 4) Give your pet a name and print their current properties.
#
# 5) Bonus: Add a "status" method to print all your pet's stats.
#
#
# The code is currently NOT functional. When you have completed this popcorn hack, the code should work. Have fun!

# %%
# %%html
# <h2>🐾 Popcorn Hack 2 - Pet Simulator 🐾</h2>
# <div id="petOutput"></div>
# <button onclick="myPet.feed()">Feed</button>
# <button onclick="myPet.play()">Play</button>
# <button onclick="myPet.describe()">Check Status</button>
#
# <script>
#   class Pet {
#     constructor(name, hunger, energy, happiness) {
#       this.name = name;
#       this.hunger = Number(hunger);
#       this.energy = Number(energy);
#       this.happiness = Number(happiness);
#     }
#
#     feed() {
#       this.hunger = Math.max(this.hunger - 3, 0); // prevent negative hunger
#       this.energy = Math.min(this.energy + 2, 10);
#       this.happiness += 1;
#       this.describe("Your pet has been fed!");
#     }
#
#     play() {
#       this.energy = Math.max(this.energy - 2, 0);
#       this.hunger = Math.min(this.hunger + 2, 10);
#       this.happiness += 3;
#       this.describe("You played with your pet!");
#     }
#
#     describe(message = "") {
#       const output = document.getElementById("petOutput");
#       output.innerHTML = `
#         <strong>${message}</strong><br>
#         <strong>Name:</strong> ${this.name}<br>
#         <strong>Hunger:</strong> ${this.hunger}<br>
#         <strong>Energy:</strong> ${this.energy}<br>
#         <strong>Happiness:</strong> ${this.happiness}<br>
#       `;
#     }
#   }
#
#   // Create a pet
#   const myPet = new Pet("Baller", 5, 5, 5);
#   myPet.describe("Meet your pet!");
# </script>
# Out:
# <h2>🐾 Popcorn Hack 2 - Pet Simulator 🐾</h2>
# <div id="petOutput"></div>
# <button onclick="myPet.feed()">Feed</button>
# <button onclick="myPet.play()">Play</button>
# <button onclick="myPet.describe()">Check Status</button>
#
# <script>
#   class Pet {
#     constructor(name, hunger, energy, happiness) {
#       this.name = name;
#       this.hunger = Number(hunger);
#       this.energy = Number(energy);
#       this.happiness = Number(happiness);
#     }
#
#     feed() {
#       this.hunger = Math.max(this.hunger - 3, 0); // prevent negative hunger
#       this.energy = Math.min(this.energy + 2, 10);
#       this.happiness += 1;
#       this.describe("Your pet has been fed!");
#     }
#
#     play() {
#       this.energy = Math.max(this.energy - 2, 0);
#       this.hunger = Math.min(this.hunger + 2, 10);
#       this.happiness += 3;
#       this.describe("You played with your pet!");
#     }
#
#     describe(message = "") {
#       const output = document.getElementById("petOutput");
#       output.innerHTML = `
#         <strong>${message}</strong><br>
#         <strong>Name:</strong> ${this.name}<br>
#         <strong>Hunger:</strong> ${this.hunger}<br>
#         <strong>Energy:</strong> ${this.energy}<br>
#         <strong>Happiness:</strong> ${this.happiness}<br>
#       `;
#     }
#   }
#
#   // Create a pet
#   const myPet = new Pet("Baller", 5, 5, 5);
#   myPet.describe("Meet your pet!");
# </script>

# %% [markdown]
# ### <u>Homework</u>
#
# Complete the following questions in the next code block.
#
# 1) Create a class Person with properties 'name' and 'age'. Print their properties.
#
# 2) Add a method greet() to your Person class that prints a greeting using the person's name.
#
# 3) Create a class Book with properties 'title', 'author', and 'pages'. Instantiate a book and print its properties.
#
# 4) Add a method read(pages) to your Book class that increments a pagesRead property and prints a message.
#
# 5) Add a method isLongBook() that returns true if pages > 300, otherwise false. Print the result for your book.
#
# 6) Create a class Car with properties 'make', 'model', and 'fuel'. Add methods drive(distance) and refuel(amount). Print messages in each method.
#
# 7) Add a static method info() to your Car class that prints 'Cars are vehicles.'
#
# 8) Create a class ElectricCar that extends Car. Add a property 'battery' and a method charge(amount) that increases battery. Print battery level after charging.
#
# 10) Create a routine that combines your objects: drive a Car, charge an ElectricCar, read pages from a Book, and call greet() on Person. Print outputs for each action.
#
# 11) **Extra Credit:** Submit the original OOP Breakout Game Code (found on [OpenCS](https://github.com/Open-Coding-Society/pages/blob/main/hacks/breakout/breakout.md?plain=1)) after making the following edits:
# - Add another feature to the game: Add a method so that the ball must collide with some bricks twice for a brick to break completely.
# - Edit a method in the ball class to increase/decrease the speed of the ball: Please add a COMMENT on the game code that specifies which line you edited.

# %%
# %%html
#
# <h2>Homework</h2>
# <div id="homeworkOutput"></div>
#
# <script>
#     class Person {
#         constructor(name, age) {
#             this.name = name;
#             this.age = Number(age);
#         }
#         greet() {
#             const output = document.getElementById("homeworkOutput");
#             output.innerHTML = "Hello, " + this.name + "!";
#         }
#     }
#     class Book {
#         constructor(title, author, pages) {
#             this.title = title;
#             this.author = author;
#             this.pages = Number(pages);
#             this.pagesRead = 0;
#         }
#         read(pages) {
#             const output = document.getElementById("homeworkOutput");
#             this.pagesRead += Number(pages);
#             output.innerHTML = "You have read " + this.pages + "pages.";
#         }
#         isLongBook() {
#             const output = document.getElementById("homeworkOutput");
#             if(this.pages >= 300) {
#                 output.innerHTML = "This book is over 300 pages";
#             }
#             else {
#                 output.innerHTML = "This book is less than 300 pages";
#             }
#         }
#     }
#     class Car {
#         constructor(make, model, fuel) {
#             this.make = make;
#             this.model = model;
#             this.fuel = Number(fuel);
#         }
#         static info() {
#             const output = document.getElementById("homeworkOutput");
#             output.innerHTML = "Cars are vehicles";
#         }
#         drive(distance) {
#         const output = document.getElementById("homeworkOutput");
#         // Assume fuel consumption: 1 unit fuel per 10 distance units
#         const fuelNeeded = distance / 10;
#         if (this.fuel >= fuelNeeded) {
#             this.fuel -= fuelNeeded;
#             output.innerHTML = `${this.make} ${this.model} drove ${distance} units.`;
#         } else {
#             output.innerHTML = `Not enough fuel to drive ${distance} units.`;
#         }
#         this.printFuel();
#         }
#
#         refuel(amount) {
#         this.fuel += amount;
#         console.log(`${this.make} ${this.model} refueled by ${amount} units.`);
#         this.printFuel();
#         }
#     }
#     class ElectricCar extends Car {
#         constructor(make, model, fuel, battery) {
#             super(make, model, fuel);
#             this.battery = Number(battery);
#         }
#         charge(amount) {
#             this.battery += amount;
#             const output = document.getElementById("homeworkOutput");
#             output.innerHTML = "Your car has been charged " + amount + " and is now at " + battery + " battery."
#         }
#     }
#
#
# </script>
# Out:
# <h2>Homework Output</h2>
# <div id="homeworkOutput"></div>
#
# <script>
#   class Person {
#     constructor(name, age) {
#       this.name = name;
#       this.age = age;
#       this.printProperties();
#     }
#     printProperties() {
#       const output = document.getElementById("homeworkOutput");
#       output.innerHTML += `Person - Name: ${this.name}, Age: ${this.age}<br>`;
#     }
#     greet() {
#       const output = document.getElementById("homeworkOutput");
#       output.innerHTML += `Hello, my name is ${this.name}!<br>`;
#     }
#   }
#
#   class Book {
#     constructor(title, author, pages) {
#       this.title = title;
#       this.author = author;
#       this.pages = pages;
#       this.pagesRead = 0;
#       this.printProperties();
#     }
#     printProperties() {
#       const output = document.getElementById("homeworkOutput");
#       output.innerHTML += `Book - Title: "${this.title}", Author: ${this.author}, Pages: ${this.pages}<br>`;
#     }
#     read(pages) {
#       this.pagesRead += pages;
#       const output = document.getElementById("homeworkOutput");
#       output.innerHTML += `You have read ${this.pagesRead} pages.<br>`;
#     }
#     isLongBook() {
#       const output = document.getElementById("homeworkOutput");
#       const result = this.pages > 300;
#       output.innerHTML += `Is "${this.title}" a long book? ${result}<br>`;
#       return result;
#     }
#   }
#
#   class Car {
#     constructor(make, model, fuel) {
#       this.make = make;
#       this.model = model;
#       this.fuel = fuel;
#       this.printProperties();
#     }
#     printProperties() {
#       const output = document.getElementById("homeworkOutput");
#       output.innerHTML += `Car - Make: ${this.make}, Model: ${this.model}, Fuel: ${this.fuel}<br>`;
#     }
#     drive(distance) {
#       const fuelNeeded = distance / 10;
#       const output = document.getElementById("homeworkOutput");
#       if (this.fuel >= fuelNeeded) {
#         this.fuel -= fuelNeeded;
#         output.innerHTML += `${this.make} ${this.model} drove ${distance} units.<br>`;
#       } else {
#         output.innerHTML += `Not enough fuel to drive ${distance} units.<br>`;
#       }
#       output.innerHTML += `Fuel left: ${this.fuel.toFixed(2)}<br>`;
#     }
#     refuel(amount) {
#       this.fuel += amount;
#       const output = document.getElementById("homeworkOutput");
#       output.innerHTML += `${this.make} ${this.model} refueled by ${amount} units. Total fuel: ${this.fuel.toFixed(2)}<br>`;
#     }
#     static info() {
#       const output = document.getElementById("homeworkOutput");
#       output.innerHTML += `Cars are vehicles.<br>`;
#     }
#   }
#
#   class ElectricCar extends Car {
#     constructor(make, model, fuel, battery) {
#       super(make, model, fuel);
#       this.battery = battery;
#       this.printProperties();
#     }
#     printProperties() {
#       const output = document.getElementById("homeworkOutput");
#       output.innerHTML += `ElectricCar - Make: ${this.make}, Model: ${this.model}, Fuel: ${this.fuel}, Battery: ${this.battery}<br>`;
#     }
#     charge(amount) {
#       this.battery += amount;
#       const output = document.getElementById("homeworkOutput");
#       output.innerHTML += `Charged battery by ${amount}. Battery level: ${this.battery}<br>`;
#     }
#   }
#
#   // Create instances and run routine:
#   const output = document.getElementById("homeworkOutput");
#   output.innerHTML += "<strong>Routine Start:</strong><br>";
#
#   const person = new Person("Alice", 30);
#   person.greet();
#
#   const book = new Book("The Great Gatsby", "F. Scott Fitzgerald", 200);
#   book.read(50);
#   book.isLongBook();
#
#   const car = new Car("Toyota", "Corolla", 10);
#   Car.info();
#   car.drive(50);
#   car.refuel(20);
#
#   const eCar = new ElectricCar("Tesla", "Model 3", 5, 50);
#   eCar.drive(20);
#   eCar.charge(30);
#
#   output.innerHTML += "<strong>Routine End.</strong>";
# </script>
